# %%
from utils.plots import plot_descarga_with_differet_frecuencies

DIR = "../simulator/src/main/resources/benchmark/omega/"

plot_descarga_with_differet_frecuencies(DIR)

# %%
from utils.plots import plot_caudal_over_frecuency

DIR = "../simulator/src/main/resources/benchmark/omega/"

plot_caudal_over_frecuency(DIR)

# %%
from utils.plots import plot_caudal_over_apertura

DIR = "../simulator/src/main/resources/benchmark/D/"

plot_caudal_over_apertura(DIR)

# %%
from utils.beverloo import plot_beverloo

PATH = '../simulator/src/main/resources/benchmark/D/caudales.txt'

plot_beverloo(PATH)
