# %%
from utils.particlesParser import parse_variating_eta_file
from utils.plots import plot_va_eta_over_iterations
import numpy as np

SAME_DENSITY_BASE = '../simulator/src/main/resources/benchmark_2000/eta_variation'
Ns = [40,100,400,4000,10000]
for n in Ns:
    TO_FILE = SAME_DENSITY_BASE + "/N_" + str(n) + ".txt"
    N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)
    plot_va_eta_over_iterations(data_dict, N, L)

# %%
from utils.particlesParser import parse_variating_eta_directory
from utils.plots import plot_va_variating_eta

TO_DIR = '../simulator/src/main/resources/benchmark_2000/eta_variation/mean'
all_data = parse_variating_eta_directory(TO_DIR)
plot_va_variating_eta(all_data)

# %%
""" from utils.particlesParser import parse_variating_eta_file
from utils.plots import parse_variating_eta_file

VARITATING_L_BASE = '../simulator/src/main/resources/benchmark_2000/eta_variation_variating_L'
Ls = [5.0, 10.0, 25.0, 50.0, 100.0, 250.0]
for l in Ls:
    TO_FILE = VARITATING_L_BASE + "/" + str(l) + ".txt"
    N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)
    plot_va_eta_over_iterations(data_dict, N, L) """
# Out:
# ' from utils.particlesParser import parse_variating_eta_file\nfrom utils.plots import parse_variating_eta_file\n\nVARITATING_L_BASE = \'../simulator/src/main/resources/benchmark_2000/eta_variation_variating_L\'\nLs = [5.0, 10.0, 25.0, 50.0, 100.0, 250.0]\nfor l in Ls:\n    TO_FILE = VARITATING_L_BASE + "/" + str(l) + ".txt"\n    N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)\n    plot_va_eta_over_iterations(data_dict, N, L) '

# %%
""" from utils.particlesParser import parse_variating_eta_file
from utils.plots import parse_variating_eta_file

VARITATING_N_BASE = '../simulator/src/main/resources/benchmark_2000/eta_variation_variating_N'
Ns = [50,100,250,500,750,1000]
for n in Ns:
    TO_FILE = VARITATING_N_BASE + "/N_" + str(n) + ".txt"
    N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)
    plot_va_eta_over_iterations(data_dict, N, L) """
# Out:
# ' from utils.particlesParser import parse_variating_eta_file\nfrom utils.plots import parse_variating_eta_file\n\nVARITATING_N_BASE = \'../simulator/src/main/resources/benchmark_2000/eta_variation_variating_N\'\nNs = [50,100,250,500,750,1000]\nfor n in Ns:\n    TO_FILE = VARITATING_N_BASE + "/N_" + str(n) + ".txt"\n    N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)\n    plot_va_eta_over_iterations(data_dict, N, L) '

# %%
""" from utils.particlesParser import parse_variating_eta_directory
from utils.plots import plot_va_variating_eta

TO_DIR = '../simulator/src/main/resources/benchmark_2000/eta_variation_variating_L'
all_data = parse_variating_eta_directory(TO_DIR)
plot_va_variating_eta(all_data) """
# Out:
# " from utils.particlesParser import parse_variating_eta_directory\nfrom utils.plots import plot_va_variating_eta\n\nTO_DIR = '../simulator/src/main/resources/benchmark_2000/eta_variation_variating_L'\nall_data = parse_variating_eta_directory(TO_DIR)\nplot_va_variating_eta(all_data) "

# %%
""" from utils.particlesParser import parse_variating_eta_directory
from utils.plots import plot_va_variating_eta

TO_DIR = '../simulator/src/main/resources/benchmark_2000/eta_variation_variating_N'
all_data = parse_variating_eta_directory(TO_DIR)
plot_va_variating_eta(all_data) """
# Out:
# " from utils.particlesParser import parse_variating_eta_directory\nfrom utils.plots import plot_va_variating_eta\n\nTO_DIR = '../simulator/src/main/resources/benchmark_2000/eta_variation_variating_N'\nall_data = parse_variating_eta_directory(TO_DIR)\nplot_va_variating_eta(all_data) "

# %%
from utils.particlesParser import parse_variating_density_file
from utils.plots import plot_va_density_over_iterations

SAME_DENSITY_BASE = '../simulator/src/main/resources/benchmark_2000/density_variation'
etas = [i for i in range(0, 5)]
for eta in etas:
    TO_FILE = SAME_DENSITY_BASE + "/eta_" + str(eta) + ".0.txt"
    eta, L, Rc, iterations, data_dict = parse_variating_density_file(TO_FILE)
    plot_va_density_over_iterations(data_dict, eta, L)

# %%
from utils.particlesParser import parse_variating_density_directory
from utils.plots import plot_va_variating_density

TO_DIR = '../simulator/src/main/resources/benchmark_2000/density_variation/mean'
all_data = parse_variating_density_directory(TO_DIR)
plot_va_variating_density(all_data)
