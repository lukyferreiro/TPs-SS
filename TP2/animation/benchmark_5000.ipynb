# %%
from utils.particlesParser import parse_variating_eta_file
from utils.plots import plot_va_eta_over_iterations

SAME_DENSITY_BASE = '../simulator/src/main/resources/benchmark_5000/eta_variation_same_density'
Ns = [40,100,400,4000, 10000]
for n in Ns:
    TO_FILE = SAME_DENSITY_BASE + "/N_" + str(n) + ".txt"
    N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)
    plot_va_eta_over_iterations(data_dict, N, L)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 8
#       6 for n in Ns:
#       7     TO_FILE = SAME_DENSITY_BASE + "/N_" + str(n) + ".txt"
# ----> 8     N, L, Rc, iterations, data_dict = parse_variating_eta_file(TO_FILE)
#       9     plot_va_eta_over_iterations(data_dict, N, L)
#
# File e:\ITBA\4º Año\Simulacion de Sistemas\TPs-SS\TP2\animation\utils\particlesParser.py:45, in parse_variating_eta_file(file_path)
#      44 def parse_variating_eta_file(file_path):
# ---> 45     with open(file_path, 'r') as file:
#      46         first_line = file.readline().strip().split()
#      47         N, L, Rc, iterations = map(float, first_line)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../simulator/src/main/resources/benchmark_5000/eta_variation_same_density/N_10000.txt'

# %%
""" from utils.particlesParser import parse_order_parameter_over_iteration
from utils.plots import plot_va_over_iterations

VARITATING_L_BASE = '../simulator/src/main/resources/benchmark_5000/eta_variation_variating_L'
Ls = [5.0,7.0,10.0,15.0,25.0,50.0,100.0]
for l in Ls:
    TO_FILE = VARITATING_L_BASE + "/L_" + str(l) + ".txt"
    N, L, Rc, iterations, data_dict = parse_order_parameter_over_iteration(TO_FILE)
    plot_va_over_iterations(data_dict, N, L) """

# %%
""" from utils.particlesParser import parse_order_parameter_over_iteration
from utils.plots import plot_va_over_iterations

VARITATING_N_BASE = '../simulator/src/main/resources/benchmark_5000/eta_variation_variating_N'
Ns = [50,100,250,500,750,1000]
for n in Ns:
    TO_FILE = VARITATING_N_BASE + "/N_" + str(n) + ".txt"
    N, L, Rc, iterations, data_dict = parse_order_parameter_over_iteration(TO_FILE)
    plot_va_over_iterations(data_dict, N, L) """

# %%
from utils.particlesParser import parse_order_parameter_directory
from utils.plots import plot_va_variating_eta

TO_DIR = '../simulator/src/main/resources/benchmark_5000/eta_variation_same_density'
all_data = parse_order_parameter_directory(TO_DIR)
plot_va_variating_eta(all_data)

# %%
from utils.particlesParser import parse_order_parameter_directory
from utils.plots import plot_va_variating_eta

TO_DIR = '../simulator/src/main/resources/benchmark_5000/eta_variation_variating_L'
all_data = parse_order_parameter_directory(TO_DIR)
plot_va_variating_eta(all_data)

# %%
from utils.particlesParser import parse_order_parameter_directory
from utils.plots import plot_va_variating_eta

TO_DIR = '../simulator/src/main/resources/benchmark_5000/eta_variation_variating_N'
all_data = parse_order_parameter_directory(TO_DIR)
plot_va_variating_eta(all_data)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
