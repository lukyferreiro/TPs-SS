# %%
import json
from utils.dataConfig import DataConfig
from utils.particlesParser import parseGasDiffusionFile
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from utils.animation import update


listN = [200, 300, 400]
listL = [0.03, 0.05, 0.07, 0.09]

for N in listN:
    for L in listL:
        particles_dict = parseGasDiffusionFile(f"D:\\PC\\Downloads\\Simulación de Sistemas\\TPs-SS\\TP3\\simulator\\src\\main\\resources\\benchmark\\N_{N}\\N_{N}_L_{L}_it_0.txt")
        animation_times = list(particles_dict.keys())
        FuncAnimation(plt.gcf(), update, frames=animation_times, fargs=(particles_dict, 0.09, L),
                        interval=1, repeat=False).save(f"simulations/simulation_N{N}_L{L}.gif")
        plt.show()
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# 0.5072308174133611
# 0.5072308174133611
# 1.007809513966996
# 1.508925969014386
# 2.010317146908292
# 2.5107955731127127
# 3.0204224451755874
# 3.5243311891615328
# 4.0266518169121435
# 4.527008764367625
# 5.031849155684195
# 5.532881403239674
# 6.045851314222939
# 6.552284360029043
# 7.058102223540577
# 7.567559177630404
# 8.071575105214986
# 8.580775757279227
# 9.099096208179503
# 9.604849850680221
# 10.108142370727991
# 10.617133100891845
# 11.11870968866018
# 11.622560136313997
# 12.122957057002937
# 12.632052180803472
# 13.13488903482965
# 13.637192074500005
# 14.142024929714143
# 14.644686357097777
# 15.151616244015704
# 15.655581088410525
# 16.166264717261804
# 16.671218004226272
# 17.17712029756747
# 17.677713563838477
# 18.179192033791512
# 18.679416097507936
# 19.179977913186974
# 19.6955492407796
# 20.197457429993598
# 20.704211306605405
# 21.21819849804337
# 21.726382881534004
# 22.22789131827141
# ...
