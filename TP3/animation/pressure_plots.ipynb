# %%
from utils.particlesParser import parseGasDiffusionFile
from utils.plots import plot_pressure_over_time

listN = [200, 300, 400]
listL = [0.03, 0.05, 0.07, 0.09]


for N in listN:
    for L in listL:
        particles_dict = parseGasDiffusionFile(f"../simulator/src/main/resources/benchmark/N_{N}/N_{N}_L_{L}_it_0.txt")
        plot_pressure_over_time(particles_dict, L, N)

# %%
from utils.plots import plot_pressure_vs_area

listN = [200, 300, 400]
arr = []

for N in listN:
    PATH = f'../simulator/src/main/resources/benchmark/N_{N}'
    arr.append(PATH)

plot_pressure_vs_area(arr)
# Out:
# Coeficiente de determinación (R^2): 0.9991
# Error estándar de la estimación (SEE): 0.0100
# Coeficiente de determinación (R^2): 0.9953
# Error estándar de la estimación (SEE): 0.0453
# Coeficiente de determinación (R^2): 0.9937
# Error estándar de la estimación (SEE): 0.0912
