# %%
from utils.particlesParser import parseGasDiffusionFile
from utils.plots import plot_pressure_over_time

listN = [200, 300, 400]
listL = [0.03, 0.05, 0.07, 0.09]

for N in listN:
    for L in listL:
        particles_dict = parseGasDiffusionFile(f"../simulator/src/main/resources/benchmark/N_{N}/N_{N}_L_{L}_it_0.txt")
        plot_pressure_over_time(particles_dict, L, N)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       7 for N in listN:
#       8     for L in listL:
# ----> 9         particles_dict = parseGasDiffusionFile(f"../simulator/src/main/resources/benchmark/N_{N}/N_{N}_L_{L}_it_0.txt")
#      10         plot_pressure_over_time(particles_dict, L, N)
#
# File e:\ITBA\4º Año\Simulacion de Sistemas\TPs-SS\TP3\animation\utils\particlesParser.py:8, in parseGasDiffusionFile(gasDiffusionFile)
#       5 data_dict = {}
#       6 current_time = None
# ----> 8 with open(gasDiffusionFile, 'r') as file:
#       9     for line in file:
#      10         line = line.strip()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../simulator/src/main/resources/benchmark/N_400/N_400_L_0.03_it_0.txt'

# %%
from utils.plots import plot_pressure_over_L

listN = [200, 300, 400]

for N in listN:
    PATH = f'../simulator/src/main/resources/benchmark/N_{N}'
    plot_pressure_over_L(PATH)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 7
#       5 for N in listN:
#       6     PATH = f'../simulator/src/main/resources/benchmark/N_{N}'
# ----> 7     plot_pressure_over_L(PATH)
#
# File e:\ITBA\4º Año\Simulacion de Sistemas\TPs-SS\TP3\animation\utils\plots.py:35, in plot_pressure_over_L(dirPath)
#      33 if filename.endswith(".txt"):
#      34     file_path = os.path.join(dirPath, filename)
# ---> 35     particles_dict = parseGasDiffusionFile(file_path)
#      37     parts = filename.split("_")
#      38     N = int(parts[1])
#
# File e:\ITBA\4º Año\Simulacion de Sistemas\TPs-SS\TP3\animation\utils\particlesParser.py:25, in parseGasDiffusionFile(gasDiffusionFile)
#      23 parts = line.split()
#      24 particle_id = int(parts[0])
# ---> 25 x_position = float(parts[1])
#      26 y_position = float(parts[2])
#      28 data_dict[current_time][particle_id] = {
#      29     'x': x_position,
#      30     'y': y_position,
#      31 }
#
# IndexError: list index out of range
