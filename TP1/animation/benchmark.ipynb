# %%
from utils.benchmarkParser import parseM_variation
from utils.benchmarkPlot import plotM_variation

BASE = '../simulator/src/main/resources'
M_VARIATION_PATH = BASE + "/M_variation"
data_dict = parseM_variation(M_VARIATION_PATH)
plotM_variation(data_dict)
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12

# %%
from utils.benchmarkParser import parseMethod_variation
from utils.benchmarkPlot import plotMethod_variation, plotErrorbarMethod_variation

# CON M = 1 (cambiar el valor en Benchamark.java para crear los datos bien)
M = 1

BASE = '../simulator/src/main/resources'
METHOD_VARIATION_PATH = BASE + "/method_variation"
data_dict_method = parseMethod_variation(METHOD_VARIATION_PATH)
plotMethod_variation(data_dict_method, M)
plotErrorbarMethod_variation(data_dict_method, M)

# %%
from utils.benchmarkParser import parseMethod_variation
from utils.benchmarkPlot import plotMethod_variation, plotErrorbarMethod_variation

# CON M = 3 (cambiar el valor en Benchamark.java para crear los datos bien)
M = 3

BASE = '../simulator/src/main/resources'
METHOD_VARIATION_PATH = BASE + "/method_variation"
data_dict_method = parseMethod_variation(METHOD_VARIATION_PATH)
plotMethod_variation(data_dict_method, M)
plotErrorbarMethod_variation(data_dict_method, M)

# %%
from utils.benchmarkParser import parseMethod_variation
from utils.benchmarkPlot import plotMethod_variation, plotErrorbarMethod_variation

# CON M = 6 (cambiar el valor en Benchamark.java para crear los datos bien)
M = 6

BASE = '../simulator/src/main/resources'
METHOD_VARIATION_PATH = BASE + "/method_variation"
data_dict_method = parseMethod_variation(METHOD_VARIATION_PATH)
plotMethod_variation(data_dict_method, M)
plotErrorbarMethod_variation(data_dict_method, M)

# %%
from utils.benchmarkParser import parseMethod_variation
from utils.benchmarkPlot import plotMethod_variation, plotErrorbarMethod_variation

# CON M = 10 (cambiar el valor en Benchamark.java para crear los datos bien)
M = 10

BASE = '../simulator/src/main/resources'
METHOD_VARIATION_PATH = BASE + "/method_variation"
data_dict_method = parseMethod_variation(METHOD_VARIATION_PATH)
plotMethod_variation(data_dict_method, M)
plotErrorbarMethod_variation(data_dict_method, M)

# %%
from utils.benchmarkParser import parseMethod_variation
from utils.benchmarkPlot import plotMethod_variation, plotErrorbarMethod_variation

# CON M = 13 (cambiar el valor en Benchamark.java para crear los datos bien)
M = 13

BASE = '../simulator/src/main/resources'
METHOD_VARIATION_PATH = BASE + "/method_variation"
data_dict_method = parseMethod_variation(METHOD_VARIATION_PATH)
plotMethod_variation(data_dict_method, M)
plotErrorbarMethod_variation(data_dict_method, M)
